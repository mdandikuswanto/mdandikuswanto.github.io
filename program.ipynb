# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns 
data = pd.read_csv("data.csv")
cm = sns.light_palette("gold", as_cmap=True)
data.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_b2c17df4_ced5_11e9_9207_f62140b21456row0_col0 {
#             background-color:  #fff3b1;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row0_col1 {
#             background-color:  #fff6c8;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row0_col2 {
#             background-color:  #ffee93;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row0_col3 {
#             background-color:  #ffeb81;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row1_col0 {
#             background-color:  #fff6c3;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row1_col1 {
#             background-color:  #ffef97;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row1_col2 {
#             background-color:  #ffde30;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row1_col3 {
#             background-color:  #ffe140;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row2_col0 {
#             background-color:  #fff5bf;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row2_col1 {
#             background-color:  #fff09d;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row2_col2 {
#             background-color:  #ffe975;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row2_col3 {
#             background-color:  #fff9d8;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row3_col0 {
#             background-color:  #ffe455;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row3_col1 {
#             background-color:  #ffe767;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row3_col2 {
#             background-color:  #ffe453;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row3_col3 {
#             background-color:  #fff0a1;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row4_col0 {
#             background-color:  #ffdc1e;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row4_col1 {
#             background-color:  #fff1a3;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row4_col2 {
#             background-color:  #ffde2e;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row4_col3 {
#             background-color:  #ffed8a;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row5_col0 {
#             background-color:  #fff1a6;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row5_col1 {
#             background-color:  #ffe037;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row5_col2 {
#             background-color:  #fff5bc;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row5_col3 {
#             background-color:  #ffe143;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row6_col0 {
#             background-color:  #ffd90e;
#             color:  #000000;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row13_col0 {
#             background-color:  #ffdd29;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row13_col1 {
#             background-color:  #fff9db;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row13_col2 {
#             background-color:  #ffe249;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row13_col3 {
#             background-color:  #ffe143;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row14_col0 {
#             background-color:  #ffdd29;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row14_col1 {
#             background-color:  #ffee91;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row14_col2 {
#             background-color:  #ffe03b;
#             color:  #000000;
#         }    #T_b2c17df4_ced5_11e9_9207_f62140b21456row14_col3 {
#             background-color:  #fff09d;

# %%
colum = data.columns.tolist()
for x in colum:
    detail=[x for x in data[x]]
    desc= data[x].describe()
    array= [x for x in desc]
    print("Detail kolom ",x)
    print("rata-rata: ",array[1])
    print("Median: ",np.median(np.array(ds)))
    print("Modus: ", stats.mode(ds))
    print("Standard deviasi: ",np.std(ds))
    print("varian: ", stats.variation(ds))
    print("Skewness: ",stats.skew(ds))
    print("Quartil 1: ",array[4])
    print("Quartil 2: ",array[5])
    print("Quartil 3: ",array[6])
    
    print("\n")
# Out:
# Detail kolom  A
# rata-rata:  149.03
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c24824c2b2d6> in <module>
#       6     print("Detail kolom ",x)
#       7     print("rata-rata: ",array[1])
# ----> 8     print("Median: ",np.median(np.array(ds)))
#       9     print("Modus: ", stats.mode(ds))
#      10     print("Standard deviasi: ",np.std(ds))
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# c:\users\afand\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3500     """
#    3501     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3502                     overwrite_input=overwrite_input)
#    3503     if keepdims:
#    3504         return r.reshape(k)
#
# c:\users\afand\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3408         keepdim = (1,) * a.ndim
#    3409
# -> 3410     r = func(a, **kwargs)
#    3411     return r, keepdim
#    3412
#
# c:\users\afand\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    3559         # Use mean in odd and even case to coerce data type
#    3560         # and check, use out array.
# -> 3561         return mean(part[indexer], axis=axis, out=out)
#    3562
#    3563
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# c:\users\afand\appdata\local\programs\python\python36\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3255
#    3256     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3257                           out=out, **kwargs)
#    3258
#    3259
#
# c:\users\afand\appdata\local\programs\python\python36\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type
